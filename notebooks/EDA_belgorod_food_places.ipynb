# %% [markdown]
# # Анализ белгородских мест общесвтенного питания
#
# ### Анализ производится из данных, которые удалось собрать при парсинге yandex карт

# %%
import numpy as np 
import pandas as pd 
import scipy.stats as sts 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('data/belgorod_food_places.csv', index_col='name')
df.head()
# Out:
#                     Unnamed: 0                                adress  rait  \
# name
# Farfor                       0       Харьковский пер., 36Д, Белгород   4.3
# Перчини Grill&Wine           1           просп. Славы, 90А, Белгород   4.5
# Ниндзя ФУД                   2           ул. Костюкова, 39, Белгород   4.7
# Дао                          3  Харьковская ул., 3, Белгород, этаж 1   4.4
# Тшм                          4     Белгородский просп., 93, Белгород   3.7
#
#                     rait_count  \
# name
# Farfor              391 оценка
# Перчини Grill&Wine      (2416)
# Ниндзя ФУД               (651)
# Дао                 407 оценок
# Тшм                 239 оценок
#
#                                                                  link  \
# name
# Farfor                  https://yandex.ru/maps/org/farfor/73233893783
# Перчини Grill&Wine  https://yandex.ru/maps/org/perchini_grill_wine...
# Ниндзя ФУД          https://yandex.ru/maps/org/nindzya_fud/1868725...
# Дао                        https://yandex.ru/maps/org/dao/17169128887
# Тшм                      https://yandex.ru/maps/org/tshm/190737174920
#
#                         closing_time               category
# name
# Farfor              Открыто до 23:00  Доставка еды и обедов
# Перчини Grill&Wine  Открыто до 23:00               Ресторан
# Ниндзя ФУД          Открыто до 23:00                   Кафе
# Дао                 Открыто до 22:00               Ресторан
# Тшм                    Круглосуточно        Быстрое питание

# %% [markdown]
# ## Колонки
# * *name* - наименование заведения общественного питания
#
# * *Unnamed* - будел удалена
#
# * *adress* - адрес заведения
#
# * *rait* - рейтинг заведения по 5-ти балльной шкале
#
# * *rait_count* - количесвто оценок
#
# * *link* - ссылка на заведение в яндекс картах
#
# * *closing_time* - время закрытия
#
# * *category* - категория зведения

# %%
df = df.drop(df.columns[[0]], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 215 entries, Farfor to Кафе шашлычная Сытое пузо
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   adress        213 non-null    object
#  1   rait          212 non-null    float64
#  2   rait_count    212 non-null    object
#  3   link          212 non-null    object
#  4   closing_time  215 non-null    object
#  5   category      213 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 11.8+ KB

# %%
df.describe()
# Out:
#              rait
# count  212.000000
# mean     4.306132
# std      0.448917
# min      1.600000
# 25%      4.100000
# 50%      4.300000
# 75%      4.500000
# max      5.000000

# %%
df.describe(include='object')
# Out:
#                           adress  rait_count  \
# count                        213         212
# unique                       194         185
# top     ул. Победы, 71, Белгород  153 оценки
# freq                           3           4
#
#                                                  link      closing_time  \
# count                                             212               215
# unique                                            210                28
# top     https://yandex.ru/maps/org/farfor/73233893783  Открыто до 23:00
# freq                                                2                43
#
#                category
# count               213
# unique               19
# top     Быстрое питание
# freq                 56

# %%
df.rait.value_counts()
# Out:
# rait
# 4.3    30
# 4.4    30
# 4.1    23
# 4.2    23
# 4.5    19
# 4.0    17
# 5.0    13
# 4.9    10
# 4.7     9
# 3.9     9
# 4.8     8
# 4.6     7
# 3.8     5
# 3.7     2
# 3.6     2
# 3.4     1
# 1.6     1
# 2.0     1
# 2.2     1
# 2.7     1
# Name: count, dtype: int64

# %%
df.rait.value_counts().hist();

# %%
df.closing_time.value_counts()
# Out:
# closing_time
# Открыто до 23:00           43
# Открыто до 22:00           42
# Открыто до 00:00           25
# Круглосуточно              21
# Открыто до 20:00           18
# Открыто до 21:00           13
# Открыто до 22:30            7
# График работы не указан     6
# Закрыто до завтра           6
# Открыто до 21:30            4
# Открыто до 17:00            4
# Открыто до 22:45            3
# Открыто до 01:00            3
# Открыто до 18:00            2
# До закрытия 30 мин          2
# Открыто до 02:00            2
# Организация переехала       2
# Закрыто до 20:00            2
# Открыто до 01:45            1
# Открыто до 21:45            1
# Открыто до 23:30            1
# Открыто до 00:02            1
# Открыто до 21:41            1
# До открытия 30 мин          1
# Открыто до 21:40            1
# Открыто до четверга         1
# Временно не работает        1
# Открыто до 19:00            1
# Name: count, dtype: int64

# %%
df.category.value_counts()
# Out:
# category
# Быстрое питание                         56
# Кафе                                    30
# Доставка еды и обедов                   28
# Ресторан                                28
# Пиццерия                                18
# Суши-бар                                14
# Бар, паб                                 8
# Кофейня                                  8
# Столовая                                 4
# Магазин кулинарии                        3
# Караоке-клуб                             2
# Кондитерская                             2
# Диетические и диабетические продукты     2
# Магазин суши и роллов                    2
# Магазин пива                             2
# Магазин продуктов                        2
# Пекарня                                  2
# Кейтеринг                                1
# Комбинат питания                         1
# Name: count, dtype: int64

# %%
df.rait.isnull().sum()
# Out:
# np.int64(3)

# %%
df[df['rait'].isnull()]
# Out:
#                                                                      adress  \
# name
# Обеды в офис г. Белгород  ул. 60 лет Октября, 2В, 10-й микрорайон, Белгород
# Кебаб                                          Привольная ул., 1А, Белгород
# Принц Пирогов                              Гражданский просп., 18, Белгород
#
#                           rait rait_count link           closing_time  \
# name
# Обеды в офис г. Белгород   NaN        NaN  NaN  Организация переехала
# Кебаб                      NaN        NaN  NaN          Круглосуточно
# Принц Пирогов              NaN        NaN  NaN  Организация переехала
#
#                                        category
# name
# Обеды в офис г. Белгород  Доставка еды и обедов
# Кебаб                           Быстрое питание
# Принц Пирогов                           Пекарня

# %% [markdown]
# ## Думая можно выбросить из датасета данных сомнительные заведения

# %%
df = df[~df['rait'].isnull()]
df['rait'] = df['rait'].astype(float)
df.rait.isnull().sum()
# Out:
# np.int64(0)

# %%
df = df[~df['rait'].isnull()]
df['rait'] = df['rait'].astype(float)
df.rait.hist();

# %% [markdown]
# ## Теперь приведем в порядок время закрытия
#
# ### Избавимся от выбросов в виде "оргинизация переехала", "закрыто до четверга" и т.п.

# %%
bad_data = [
    'График работы не указан', 'Закрыто до завтра', 
    'До закрытия 30 мин', 'Организация переехала',
    'Закрыто до 20:00', 'До открытия 30 мин', 
    'Открыто до четверга', 'Временно не работает'
]

df = df[~df['closing_time'].isin(bad_data)]

def convert_to_time(closing_time):
    if closing_time == "Круглосуточно":
        return pd.to_datetime("12:12", format="%H:%M").time()
    
    elif "Открыто до" in closing_time:
        time_str = closing_time.split(" ")[-1]
        return pd.to_datetime(time_str, format="%H:%M").time()
    
    return None

df['closing_time'] = df['closing_time'].apply(convert_to_time)

df = df.dropna()

df['closing_time'] = df['closing_time'].apply(lambda x: x.strftime('%H:%M'))

print(df['closing_time'].value_counts())
# Out:
# closing_time
# 23:00    43
# 22:00    42
# 00:00    25
# 12:12    20
# 20:00    17
# 21:00    10
# 22:30     7
# 21:30     4
# 17:00     4
# 22:45     3
# 01:00     3
# 02:00     2
# 18:00     2
# 23:30     1
# 01:45     1
# 21:45     1
# 00:02     1
# 21:41     1
# 21:40     1
# 19:00     1
# Name: count, dtype: int64

# %%
df.closing_time.value_counts().plot(kind='barh');

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 189 entries, Farfor to Кафе шашлычная Сытое пузо
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   adress        189 non-null    object
#  1   rait          189 non-null    float64
#  2   rait_count    189 non-null    object
#  3   link          189 non-null    object
#  4   closing_time  189 non-null    object
#  5   category      189 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 10.3+ KB

# %% [markdown]
# ## Теперь приведем порядок количество оценок

# %%
def parse_rait_count(rait_count):
    res = ""
    for ch in rait_count:
        if ch.isdigit():
            res += ch
            
    return int(res) if len(res) > 0 else None

df['rait_count'] = df['rait_count'].apply(parse_rait_count)
df.rait_count.value_counts()
# Out:
# rait_count
# 153     4
# 118     3
# 391     3
# 13      3
# 2416    2
#        ..
# 110     1
# 293     1
# 133     1
# 8       1
# 9       1
# Name: count, Length: 165, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 189 entries, Farfor to Кафе шашлычная Сытое пузо
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   adress        189 non-null    object
#  1   rait          189 non-null    float64
#  2   rait_count    189 non-null    int64
#  3   link          189 non-null    object
#  4   closing_time  189 non-null    object
#  5   category      189 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 10.3+ KB

# %%
df.rait_count.isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Проанализируем зависимость рейтинга от количества оценок
#
# #### Для этого отобразим взаимосвязь с помощью точечного графика

# %%
plt.scatter(df.rait, df.rait_count, color='red', alpha=0.5)
plt.xlabel('Рейтинг')
plt.ylabel('Количество оценок');

# %%
plt.hist(df.rait_count, bins=20, color='red', alpha=0.5);

# %% [markdown]
# ### Наблюдаем длинный хвост. Переведем в логарифмический масштаб

# %%
log_values = df.rait_count.apply(np.log)

plt.hist(log_values, bins=30, color='red', alpha=0.5, density=True)

sns.kdeplot(log_values, color='blue', linewidth=2);

# %%
sns.boxplot(df.rait_count.apply(np.log));

# %%
df.rait.value_counts().plot(kind='barh');

# %%
log_values = df.rait.apply(np.log)

plt.hist(log_values, bins=10, color='red', alpha=0.5, density=True)

sns.kdeplot(log_values, color='blue', linewidth=2);

# %%
numeric_df = df.select_dtypes(include=[np.number])

correlation_matrix = numeric_df.corr()

plt.subplots(figsize=(12, 12))
sns.heatmap(correlation_matrix, square=True,
            annot=True, fmt='.1f', linewidths=0.1);

# %%
plt.figure(figsize=(9, 9))
plt.scatter(np.log(df.rait), np.log(df.rait_count), color='red', alpha=0.7)
plt.title("Отношение рейтинга к количеству оценок")
plt.xlabel("Логарифм рейтинга")
plt.ylabel("Логарифм количества оценок")
plt.show()

# %%
df_sort = df.sort_values(by='rait', ascending=False, inplace=True)
df[:30]
# Out:
#                                                                     adress  \
# name
# Сидрерия                 ул. Костюкова, 36Г, Белгород, БЦ Владимирский,...
# Forest grill                              Гражданский просп., 34, Белгород
# Кофе и Баббл Ти                                  ул. Победы, 104, Белгород
# Кулинария                               просп. Славы, 47, Белгород, этаж 1
# Барашек                                     Корочанская ул., 39В, Белгород
# Мидийное место                                    ул. Попова, 36, Белгород
# Кофе Вино                               ул. Мичурина, 52, Белгород, этаж 1
# Ташир Пицца              просп. Богдана Хмельницкого, 137Т, Белгород, Т...
# Комод                                  ул. Костюкова, 69, Белгород, этаж 1
# Лес и Лис                           Волчанская ул., 292Б, Белгород, этаж 1
# Pitnica                                   Преображенская ул., 86, Белгород
# ПАРА-пицца                                     ул. Горького, 76А, Белгород
# Грин фиш                                ул. Губкина, 17И, Белгород, этаж 1
# Катана                              Студенческая ул., 6Б, Белгород, этаж 1
# Веретено                                    Волчанская ул., 280А, Белгород
# Виноград                                  Преображенская ул., 86, Белгород
# Амбер                                  просп. Славы, 39А, Белгород, этаж 1
# Lazy Food                Магистральная ул., 8, рабочий посёлок Северный...
# Кроко пицца и роллы            3-я Апрельская ул., 17, посёлок Новосадовый
# Сашими                                    бул. Юности, 2, Белгород, этаж 1
# Галерея                       Зелёный пер., 1А, село Соломино, помещение 2
# Смокерная                                        Садовая ул., 3Б, Белгород
# Сахар                            просп. Богдана Хмельницкого, 79, Белгород
# Vasilchuki Chaihona № 1       Донецкая ул., 93, Белгород, ул. Донецкая, 93
# Чучело                                Народный бул., 79Б, Белгород, этаж 1
# Бидон                                        просп. Ватутина, 5Г, Белгород
# Башня                                   просп. Славы, 55, Белгород, этаж 1
# Белшашлык                                        ул. Попова, 76А, Белгород
# Mesto Grill                       Свято-Троицкий бул., 7, Белгород, этаж 1
# Восточный Смак                             Корочанская ул., 493А, Белгород
#
#                          rait  rait_count  \
# name
# Сидрерия                  5.0        2162
# Forest grill              5.0        2059
# Кофе и Баббл Ти           5.0         457
# Кулинария                 5.0        1986
# Барашек                   5.0        2309
# Мидийное место            5.0        1027
# Кофе Вино                 5.0        1214
# Ташир Пицца               5.0         129
# Комод                     5.0        1736
# Лес и Лис                 4.9        3061
# Pitnica                   4.9        1822
# ПАРА-пицца                4.9         262
# Грин фиш                  4.9         115
# Катана                    4.9         431
# Веретено                  4.9        1062
# Виноград                  4.9         688
# Амбер                     4.9         758
# Lazy Food                 4.9         333
# Кроко пицца и роллы       4.9         231
# Сашими                    4.8         118
# Галерея                   4.8         798
# Смокерная                 4.8         194
# Сахар                     4.8         231
# Vasilchuki Chaihona № 1   4.8        1810
# Чучело                    4.8         146
# Бидон                     4.8         983
# Башня                     4.7        1101
# Белшашлык                 4.7         469
# Mesto Grill               4.7        1681
# Восточный Смак            4.7        1756
#
#                                                                       link  \
# name
# Сидрерия                  https://yandex.ru/maps/org/sidreriya/35871937040
# Forest grill             https://yandex.ru/maps/org/forest_grill/126721...
# Кофе и Баббл Ти          https://yandex.ru/maps/org/kofe_i_babbl_ti/962...
# Кулинария                 https://yandex.ru/maps/org/kulinariya/1088408839
# Барашек                    https://yandex.ru/maps/org/barashek/33147398141
# Мидийное место           https://yandex.ru/maps/org/midiynoye_mesto/621...
# Кофе Вино                https://yandex.ru/maps/org/kofe_vino/220415394217
# Ташир Пицца              https://yandex.ru/maps/org/tashir_pitstsa/1149...
# Комод                          https://yandex.ru/maps/org/komod/1774277670
# Лес и Лис                 https://yandex.ru/maps/org/les_i_lis/60532692927
# Pitnica                     https://yandex.ru/maps/org/pitnica/87837556709
# ПАРА-пицца               https://yandex.ru/maps/org/para_pitstsa/866919...
# Грин фиш                  https://yandex.ru/maps/org/grin_fish/45623384314
# Катана                      https://yandex.ru/maps/org/katana/229212157130
# Веретено                    https://yandex.ru/maps/org/vereteno/1232425820
# Виноград                   https://yandex.ru/maps/org/vinograd/28691424978
# Амбер                        https://yandex.ru/maps/org/amber/164156250545
# Lazy Food                https://yandex.ru/maps/org/lazy_food/209460072215
# Кроко пицца и роллы      https://yandex.ru/maps/org/kroko_pitstsa_i_rol...
# Сашими                      https://yandex.ru/maps/org/sashimi/54126388682
# Галерея                   https://yandex.ru/maps/org/galereya/149854503334
# Смокерная                https://yandex.ru/maps/org/smokernaya/16733042178
# Сахар                       https://yandex.ru/maps/org/sakhar/220267115404
# Vasilchuki Chaihona № 1  https://yandex.ru/maps/org/vasilchuki_chaihona...
# Чучело                      https://yandex.ru/maps/org/chuchelo/2217110393
# Бидон                         https://yandex.ru/maps/org/bidon/34459843530
# Башня                        https://yandex.ru/maps/org/bashnya/1365292204
# Белшашлык                https://yandex.ru/maps/org/belshashlyk/4382647...
# Mesto Grill              https://yandex.ru/maps/org/mesto_grill/5869667...
# Восточный Смак           https://yandex.ru/maps/org/vostochny_smak/1752...
#
#                         closing_time               category
# name
# Сидрерия                       00:00               Бар, паб
# Forest grill                   00:00               Ресторан
# Кофе и Баббл Ти                21:00                Кофейня
# Кулинария                      21:00      Магазин кулинарии
# Барашек                        00:00               Ресторан
# Мидийное место                 23:00               Ресторан
# Кофе Вино                      23:00                Кофейня
# Ташир Пицца                    22:00               Пиццерия
# Комод                          23:00                Кофейня
# Лес и Лис                      23:00               Ресторан
# Pitnica                        00:00               Бар, паб
# ПАРА-пицца                     22:00  Доставка еды и обедов
# Грин фиш                       22:45  Доставка еды и обедов
# Катана                         22:45  Доставка еды и обедов
# Веретено                       00:00               Ресторан
# Виноград                       00:00               Ресторан
# Амбер                          00:00               Бар, паб
# Lazy Food                      22:00  Доставка еды и обедов
# Кроко пицца и роллы            21:30  Доставка еды и обедов
# Сашими                         21:41  Доставка еды и обедов
# Галерея                        00:00               Ресторан
# Смокерная                      22:00  Доставка еды и обедов
# Сахар                          23:00                Кофейня
# Vasilchuki Chaihona № 1        01:00               Ресторан
# Чучело                         00:00               Бар, паб
# Бидон                          23:00               Ресторан
# Башня                          00:00               Ресторан
# Белшашлык                      12:12        Быстрое питание
# Mesto Grill                    00:00               Ресторан
# Восточный Смак                 12:12        Быстрое питание

# %%
df[(df['rait'] >= 4.5) & (df['rait_count'] >= 1000)]
# Out:
#                                                                     adress  \
# name
# Сидрерия                 ул. Костюкова, 36Г, Белгород, БЦ Владимирский,...
# Forest grill                              Гражданский просп., 34, Белгород
# Кулинария                               просп. Славы, 47, Белгород, этаж 1
# Барашек                                     Корочанская ул., 39В, Белгород
# Мидийное место                                    ул. Попова, 36, Белгород
# Кофе Вино                               ул. Мичурина, 52, Белгород, этаж 1
# Комод                                  ул. Костюкова, 69, Белгород, этаж 1
# Лес и Лис                           Волчанская ул., 292Б, Белгород, этаж 1
# Pitnica                                   Преображенская ул., 86, Белгород
# Веретено                                    Волчанская ул., 280А, Белгород
# Vasilchuki Chaihona № 1       Донецкая ул., 93, Белгород, ул. Донецкая, 93
# Башня                                   просп. Славы, 55, Белгород, этаж 1
# Mesto Grill                       Свято-Троицкий бул., 7, Белгород, этаж 1
# Восточный Смак                             Корочанская ул., 493А, Белгород
# Ale House                                  ул. Щорса, 93, Белгород, этаж 1
# Дикая утка                       Преображенская ул., 63Б, Белгород, этаж 1
# Томато                                            ул. Попова, 17, Белгород
# Артель                                          ул. Королёва, 4Д, Белгород
# Вкусно — и точка               просп. Богдана Хмельницкого, 160А, Белгород
# Перчини Grill&Wine                             просп. Славы, 90А, Белгород
# Benny Kitchen                        ул. Николая Островского, 27, Белгород
# Перчини Grill&Wine                             просп. Славы, 90А, Белгород
#
#                          rait  rait_count  \
# name
# Сидрерия                  5.0        2162
# Forest grill              5.0        2059
# Кулинария                 5.0        1986
# Барашек                   5.0        2309
# Мидийное место            5.0        1027
# Кофе Вино                 5.0        1214
# Комод                     5.0        1736
# Лес и Лис                 4.9        3061
# Pitnica                   4.9        1822
# Веретено                  4.9        1062
# Vasilchuki Chaihona № 1   4.8        1810
# Башня                     4.7        1101
# Mesto Grill               4.7        1681
# Восточный Смак            4.7        1756
# Ale House                 4.7        2693
# Дикая утка                4.7        1050
# Томато                    4.6        1138
# Артель                    4.5        1234
# Вкусно — и точка          4.5        1218
# Перчини Grill&Wine        4.5        2416
# Benny Kitchen             4.5        1248
# Перчини Grill&Wine        4.5        2416
#
#                                                                       link  \
# name
# Сидрерия                  https://yandex.ru/maps/org/sidreriya/35871937040
# Forest grill             https://yandex.ru/maps/org/forest_grill/126721...
# Кулинария                 https://yandex.ru/maps/org/kulinariya/1088408839
# Барашек                    https://yandex.ru/maps/org/barashek/33147398141
# Мидийное место           https://yandex.ru/maps/org/midiynoye_mesto/621...
# Кофе Вино                https://yandex.ru/maps/org/kofe_vino/220415394217
# Комод                          https://yandex.ru/maps/org/komod/1774277670
# Лес и Лис                 https://yandex.ru/maps/org/les_i_lis/60532692927
# Pitnica                     https://yandex.ru/maps/org/pitnica/87837556709
# Веретено                    https://yandex.ru/maps/org/vereteno/1232425820
# Vasilchuki Chaihona № 1  https://yandex.ru/maps/org/vasilchuki_chaihona...
# Башня                        https://yandex.ru/maps/org/bashnya/1365292204
# Mesto Grill              https://yandex.ru/maps/org/mesto_grill/5869667...
# Восточный Смак           https://yandex.ru/maps/org/vostochny_smak/1752...
# Ale House                  https://yandex.ru/maps/org/ale_house/1390148821
# Дикая утка               https://yandex.ru/maps/org/dikaya_utka/1337269...
# Томато                       https://yandex.ru/maps/org/tomato/58409121216
# Артель                       https://yandex.ru/maps/org/artel/115849083421
# Вкусно — и точка         https://yandex.ru/maps/org/vkusno_i_tochka/337...
# Перчини Grill&Wine       https://yandex.ru/maps/org/perchini_grill_wine...
# Benny Kitchen            https://yandex.ru/maps/org/benny_kitchen/11496...
# Перчини Grill&Wine       https://yandex.ru/maps/org/perchini_grill_wine...
#
#                         closing_time           category
# name
# Сидрерия                       00:00           Бар, паб
# Forest grill                   00:00           Ресторан
# Кулинария                      21:00  Магазин кулинарии
# Барашек                        00:00           Ресторан
# Мидийное место                 23:00           Ресторан
# Кофе Вино                      23:00            Кофейня
# Комод                          23:00            Кофейня
# Лес и Лис                      23:00           Ресторан
# Pitnica                        00:00           Бар, паб
# Веретено                       00:00           Ресторан
# Vasilchuki Chaihona № 1        01:00           Ресторан
# Башня                          00:00           Ресторан
# Mesto Grill                    00:00           Ресторан
# Восточный Смак                 12:12    Быстрое питание
# Ale House                      23:30           Бар, паб
# Дикая утка                     23:00               Кафе
# Томато                         22:00           Ресторан
# Артель                         00:02               Кафе
# Вкусно — и точка               22:00    Быстрое питание
# Перчини Grill&Wine             23:00           Ресторан
# Benny Kitchen                  00:00               Кафе
# Перчини Grill&Wine             23:00           Ресторан

# %%
df[df['category'] == 'Быстрое питание'][:30]
# Out:
#                                                                   adress  \
# name
# Белшашлык                                      ул. Попова, 76А, Белгород
# Восточный Смак                           Корочанская ул., 493А, Белгород
# Вкусно — и точка             просп. Богдана Хмельницкого, 160А, Белгород
# Восточное бистро             Белгородский просп., 87А, корп. 2, Белгород
# Вкусно — и точка                                 ул. Щорса, 64, Белгород
# Бургер Кинг            ул. Щорса, 64, микрорайон Пригородный, посёлок...
# Шашлык31.рф                               Промышленная ул., 15, Белгород
# Вкусно — и точка       просп. Богдана Хмельницкого, 137Т, Белгород, э...
# Смак Восточный                                Сумская ул., 70В, Белгород
# Тук-Тук                                         ул. Попова, 58, Белгород
# Вкусно — и точка                       Белгородский просп., 87, Белгород
# Еда'ки                      ул. Макаренко, 12, корп. 6, Белгород, этаж 1
# KFC                    Белгородский просп., 87, Белгород, ТК Централь...
# Бургер Кинг            просп. Богдана Хмельницкого, 137Т, Белгород, Т...
# Грильная                                   просп. Ватутина, 9Б, Белгород
# Восточный смак                   Лесная ул., 1И, посёлок Дубовое, этаж 1
# Восточный смак                    ул. Серафимовича, 67, Белгород, этаж 1
# The GriLL              ул. 50-летия Белгородской области, 19, Белгоро...
# Восточный смак                                  ул. Победы, 71, Белгород
# KFC Авто                      просп. Богдана Хмельницкого, 18А, Белгород
# Оранжевый остров                     Вокзальная ул., 2, Белгород, этаж 1
# KFC                           просп. Богдана Хмельницкого, 18А, Белгород
# Грильная 31                                    ул. Победы, 85А, Белгород
# Шаурма & Гриль                              ул. Костюкова, 39А, Белгород
# Subway                                         ул. Победы, 118, Белгород
# Кафе быстрого питания                         ул. Горького, 54, Белгород
# KFC                    просп. Богдана Хмельницкого, 137Т, Белгород, М...
# Быстрое питание                           Студенческая ул., 1К, Белгород
# Восточный смак                                ул. Губкина, 22А, Белгород
# Шаурмаг                                      просп. Славы, 159, Белгород
#
#                        rait  rait_count  \
# name
# Белшашлык               4.7         469
# Восточный Смак          4.7        1756
# Вкусно — и точка        4.5        1218
# Восточное бистро        4.5         467
# Вкусно — и точка        4.4        1688
# Бургер Кинг             4.4        1913
# Шашлык31.рф             4.4          97
# Вкусно — и точка        4.4         139
# Смак Восточный          4.4         332
# Тук-Тук                 4.4         351
# Вкусно — и точка        4.4         376
# Еда'ки                  4.4         240
# KFC                     4.3        1300
# Бургер Кинг             4.3         486
# Грильная                4.3         117
# Восточный смак          4.3         404
# Восточный смак          4.3         391
# The GriLL               4.3         195
# Восточный смак          4.3         708
# KFC Авто                4.2        1160
# Оранжевый остров        4.2         118
# KFC                     4.2         526
# Грильная 31             4.2          68
# Шаурма & Гриль          4.2         135
# Subway                  4.2         147
# Кафе быстрого питания   4.2          96
# KFC                     4.2         608
# Быстрое питание         4.2           8
# Восточный смак          4.1         316
# Шаурмаг                 4.1         124
#
#                                                                     link  \
# name
# Белшашлык              https://yandex.ru/maps/org/belshashlyk/4382647...
# Восточный Смак         https://yandex.ru/maps/org/vostochny_smak/1752...
# Вкусно — и точка       https://yandex.ru/maps/org/vkusno_i_tochka/337...
# Восточное бистро       https://yandex.ru/maps/org/vostochnoye_bistro/...
# Вкусно — и точка       https://yandex.ru/maps/org/vkusno_i_tochka/115...
# Бургер Кинг            https://yandex.ru/maps/org/burger_king/2097118...
# Шашлык31.рф            https://yandex.ru/maps/org/shashlyk31_rf/22020...
# Вкусно — и точка       https://yandex.ru/maps/org/vkusno_i_tochka/665...
# Смак Восточный         https://yandex.ru/maps/org/smak_vostochny/1939...
# Тук-Тук                   https://yandex.ru/maps/org/tuk_tuk/38349068751
# Вкусно — и точка       https://yandex.ru/maps/org/vkusno_i_tochka/265...
# Еда'ки                   https://yandex.ru/maps/org/yeda_ki/117636070481
# KFC                            https://yandex.ru/maps/org/kfc/1321687128
# Бургер Кинг            https://yandex.ru/maps/org/burger_king/2277996...
# Грильная                  https://yandex.ru/maps/org/grilnaya/1754398421
# Восточный смак         https://yandex.ru/maps/org/vostochny_smak/2247...
# Восточный смак         https://yandex.ru/maps/org/vostochny_smak/1834...
# The GriLL               https://yandex.ru/maps/org/the_grill/42734842862
# Восточный смак         https://yandex.ru/maps/org/vostochny_smak/1799...
# KFC Авто                 https://yandex.ru/maps/org/kfc_avto/91033790754
# Оранжевый остров       https://yandex.ru/maps/org/oranzhevy_ostrov/10...
# KFC                           https://yandex.ru/maps/org/kfc/81916251006
# Грильная 31            https://yandex.ru/maps/org/grilnaya_31/2164849...
# Шаурма & Гриль         https://yandex.ru/maps/org/shaurma_gril/118153...
# Subway                      https://yandex.ru/maps/org/subway/1385697254
# Кафе быстрого питания  https://yandex.ru/maps/org/kafe_bystrogo_pitan...
# KFC                            https://yandex.ru/maps/org/kfc/1317458048
# Быстрое питание        https://yandex.ru/maps/org/bystroye_pitaniye/2...
# Восточный смак         https://yandex.ru/maps/org/vostochny_smak/2388...
# Шаурмаг                 https://yandex.ru/maps/org/shaurmag/197109103251
#
#                       closing_time         category
# name
# Белшашлык                    12:12  Быстрое питание
# Восточный Смак               12:12  Быстрое питание
# Вкусно — и точка             22:00  Быстрое питание
# Восточное бистро             02:00  Быстрое питание
# Вкусно — и точка             20:00  Быстрое питание
# Бургер Кинг                  22:00  Быстрое питание
# Шашлык31.рф                  22:00  Быстрое питание
# Вкусно — и точка             23:00  Быстрое питание
# Смак Восточный               12:12  Быстрое питание
# Тук-Тук                      12:12  Быстрое питание
# Вкусно — и точка             00:00  Быстрое питание
# Еда'ки                       22:00  Быстрое питание
# KFC                          22:00  Быстрое питание
# Бургер Кинг                  22:00  Быстрое питание
# Грильная                     01:00  Быстрое питание
# Восточный смак               12:12  Быстрое питание
# Восточный смак               12:12  Быстрое питание
# The GriLL                    23:00  Быстрое питание
# Восточный смак               12:12  Быстрое питание
# KFC Авто                     00:00  Быстрое питание
# Оранжевый остров             21:00  Быстрое питание
# KFC                          22:00  Быстрое питание
# Грильная 31                  20:00  Быстрое питание
# Шаурма & Гриль               23:00  Быстрое питание
# Subway                       23:00  Быстрое питание
# Кафе быстрого питания        21:00  Быстрое питание
# KFC                          22:00  Быстрое питание
# Быстрое питание              17:00  Быстрое питание
# Восточный смак               12:12  Быстрое питание
# Шаурмаг                      22:00  Быстрое питание

# %%
dict_category = dict(df.category.value_counts())
dict_category
# Out:
# {'Быстрое питание': np.int64(50),
#  'Кафе': np.int64(29),
#  'Ресторан': np.int64(26),
#  'Доставка еды и обедов': np.int64(24),
#  'Пиццерия': np.int64(17),
#  'Суши-бар': np.int64(14),
#  'Кофейня': np.int64(7),
#  'Бар, паб': np.int64(6),
#  'Магазин кулинарии': np.int64(3),
#  'Столовая': np.int64(2),
#  'Магазин суши и роллов': np.int64(2),
#  'Кондитерская': np.int64(2),
#  'Магазин пива': np.int64(2),
#  'Пекарня': np.int64(1),
#  'Кейтеринг': np.int64(1),
#  'Диетические и диабетические продукты': np.int64(1),
#  'Магазин продуктов': np.int64(1),
#  'Комбинат питания': np.int64(1)}

# %%
plt.figure(figsize=(9, 9))
df.category.value_counts().plot(kind='barh', color='red', alpha=0.5);

# %%
bad_data = []

def parse_category(category):
    for key, value in category.items(): 
        if value < 5 or key == 'Бар, паб':
            bad_data.append(key) 
            
parse_category(dict_category)
bad_data
# Out:
# ['Бар, паб',
#  'Магазин кулинарии',
#  'Столовая',
#  'Магазин суши и роллов',
#  'Кондитерская',
#  'Магазин пива',
#  'Пекарня',
#  'Кейтеринг',
#  'Диетические и диабетические продукты',
#  'Магазин продуктов',
#  'Комбинат питания']

# %%
clear_df = df[~df['category'].isin(bad_data)]

clear_df.category.value_counts()
# Out:
# category
# Быстрое питание          50
# Кафе                     29
# Ресторан                 26
# Доставка еды и обедов    24
# Пиццерия                 17
# Суши-бар                 14
# Кофейня                   7
# Name: count, dtype: int64

# %% [markdown]
# ### Выбирем самые лучшие заведения. Будем считать лучшим те, у которых рейтинг больше 4.5 и больше 120 оценок

# %%
best_df = clear_df[(clear_df['rait'] >= 4.5) & (clear_df['rait_count'] >= 120)]
best_df.count()
# Out:
# adress          45
# rait            45
# rait_count      45
# link            45
# closing_time    45
# category        45
# dtype: int64

# %% [markdown]
# #### Всего 45 заведений. Посмтрим на их категории

# %%
best_df.category.value_counts().plot(kind='barh', color='red', alpha=0.5);
best_df.groupby('category')['rait'].mean().sort_values(ascending=False).plot(kind='barh', color='red', alpha=0.5);
best_df.groupby('category')['rait_count'].mean().sort_values(ascending=False).plot(kind='barh', color='red', alpha=0.5);
best_df.groupby('category')['rait'].mean().sort_values(ascending=False)
best_df.groupby('category')['rait_count'].mean().sort_values(ascending=False)
best_df.groupby('category')['rait'].mean().sort_values(ascending=False).plot(kind='barh', color='red', alpha=0.5);

# %%
best_df.category.value_counts()
# Out:
# category
# Ресторан                 16
# Доставка еды и обедов     9
# Кафе                      6
# Кофейня                   5
# Пиццерия                  5
# Быстрое питание           4
# Name: count, dtype: int64

# %%
best_df.groupby('category')['rait'].mean().sort_values
# Out:
# <bound method Series.sort_values of category
# Быстрое питание          4.600000
# Доставка еды и обедов    4.744444
# Кафе                     4.583333
# Кофейня                  4.880000
# Пиццерия                 4.660000
# Ресторан                 4.756250
# Name: rait, dtype: float64>

# %% [markdown]
# #### Получается, что наибольший средний рейтинг у кофейнь, ресторанов и доставок еды и обедов

# %%
best_df.sort_values(by='rait', ascending=False)
# Out:
#                                                                     adress  \
# name
# Forest grill                              Гражданский просп., 34, Белгород
# Кофе и Баббл Ти                                  ул. Победы, 104, Белгород
# Барашек                                     Корочанская ул., 39В, Белгород
# Мидийное место                                    ул. Попова, 36, Белгород
# Кофе Вино                               ул. Мичурина, 52, Белгород, этаж 1
# Ташир Пицца              просп. Богдана Хмельницкого, 137Т, Белгород, Т...
# Комод                                  ул. Костюкова, 69, Белгород, этаж 1
# Лес и Лис                           Волчанская ул., 292Б, Белгород, этаж 1
# ПАРА-пицца                                     ул. Горького, 76А, Белгород
# Катана                              Студенческая ул., 6Б, Белгород, этаж 1
# Веретено                                    Волчанская ул., 280А, Белгород
# Виноград                                  Преображенская ул., 86, Белгород
# Lazy Food                Магистральная ул., 8, рабочий посёлок Северный...
# Кроко пицца и роллы            3-я Апрельская ул., 17, посёлок Новосадовый
# Галерея                       Зелёный пер., 1А, село Соломино, помещение 2
# Смокерная                                        Садовая ул., 3Б, Белгород
# Сахар                            просп. Богдана Хмельницкого, 79, Белгород
# Vasilchuki Chaihona № 1       Донецкая ул., 93, Белгород, ул. Донецкая, 93
# Бидон                                        просп. Ватутина, 5Г, Белгород
# Башня                                   просп. Славы, 55, Белгород, этаж 1
# Белшашлык                                        ул. Попова, 76А, Белгород
# Mesto Grill                       Свято-Троицкий бул., 7, Белгород, этаж 1
# Восточный Смак                             Корочанская ул., 493А, Белгород
# Стэйси пицца                                    просп. Славы, 86, Белгород
# Дикая утка                       Преображенская ул., 63Б, Белгород, этаж 1
# Ниндзя ФУД                                     ул. Костюкова, 39, Белгород
# Азбука Хлеба                             Преображенская ул., 106, Белгород
# Yellowcafe.ru                             ул. Щорса, 45Л, Белгород, этаж 1
# Мир шашлыка                               Владимирский пер., 11А, Белгород
# Томато                                            ул. Попова, 17, Белгород
# Ташир Пицца              просп. Богдана Хмельницкого, 164, Белгород, ТЦ...
# Surf Coffee X Friends                     Свято-Троицкий бул., 7, Белгород
# Ташир Пицца              ул. Щорса, 64, микрорайон Пригородный, посёлок...
# Корчма                                            ул. Щорса, 45А, Белгород
# Артель                                          ул. Королёва, 4Д, Белгород
# Корчма                            Гражданский просп., 18, Белгород, этаж 1
# Вкусно — и точка               просп. Богдана Хмельницкого, 160А, Белгород
# Между палок                                   ул. Апанасенко, 97, Белгород
# Суши ням                     ул. 3-го Интернационала, 25, Белгород, этаж 1
# Перчини Grill&Wine                             просп. Славы, 90А, Белгород
# Benny Kitchen                        ул. Николая Островского, 27, Белгород
# Старик Хинкалыч          ул. Щорса, 64, Белгород, МТРК СитиМолл Белгоро...
# Восточное бистро               Белгородский просп., 87А, корп. 2, Белгород
# Пицца 32 СМ                                     ул. Мичурина, 52, Белгород
# Перчини Grill&Wine                             просп. Славы, 90А, Белгород
#
#                          rait  rait_count  \
# name
# Forest grill              5.0        2059
# Кофе и Баббл Ти           5.0         457
# Барашек                   5.0        2309
# Мидийное место            5.0        1027
# Кофе Вино                 5.0        1214
# Ташир Пицца               5.0         129
# Комод                     5.0        1736
# Лес и Лис                 4.9        3061
# ПАРА-пицца                4.9         262
# Катана                    4.9         431
# Веретено                  4.9        1062
# Виноград                  4.9         688
# Lazy Food                 4.9         333
# Кроко пицца и роллы       4.9         231
# Галерея                   4.8         798
# Смокерная                 4.8         194
# Сахар                     4.8         231
# Vasilchuki Chaihona № 1   4.8        1810
# Бидон                     4.8         983
# Башня                     4.7        1101
# Белшашлык                 4.7         469
# Mesto Grill               4.7        1681
# Восточный Смак            4.7        1756
# Стэйси пицца              4.7         448
# Дикая утка                4.7        1050
# Ниндзя ФУД                4.7         651
# Азбука Хлеба              4.7         129
# Yellowcafe.ru             4.6         471
# Мир шашлыка               4.6         358
# Томато                    4.6        1138
# Ташир Пицца               4.6         167
# Surf Coffee X Friends     4.6         375
# Ташир Пицца               4.5         133
# Корчма                    4.5         942
# Артель                    4.5        1234
# Корчма                    4.5         599
# Вкусно — и точка          4.5        1218
# Между палок               4.5         258
# Суши ням                  4.5         168
# Перчини Grill&Wine        4.5        2416
# Benny Kitchen             4.5        1248
# Старик Хинкалыч           4.5         592
# Восточное бистро          4.5         467
# Пицца 32 СМ               4.5         500
# Перчини Grill&Wine        4.5        2416
#
#                                                                       link  \
# name
# Forest grill             https://yandex.ru/maps/org/forest_grill/126721...
# Кофе и Баббл Ти          https://yandex.ru/maps/org/kofe_i_babbl_ti/962...
# Барашек                    https://yandex.ru/maps/org/barashek/33147398141
# Мидийное место           https://yandex.ru/maps/org/midiynoye_mesto/621...
# Кофе Вино                https://yandex.ru/maps/org/kofe_vino/220415394217
# Ташир Пицца              https://yandex.ru/maps/org/tashir_pitstsa/1149...
# Комод                          https://yandex.ru/maps/org/komod/1774277670
# Лес и Лис                 https://yandex.ru/maps/org/les_i_lis/60532692927
# ПАРА-пицца               https://yandex.ru/maps/org/para_pitstsa/866919...
# Катана                      https://yandex.ru/maps/org/katana/229212157130
# Веретено                    https://yandex.ru/maps/org/vereteno/1232425820
# Виноград                   https://yandex.ru/maps/org/vinograd/28691424978
# Lazy Food                https://yandex.ru/maps/org/lazy_food/209460072215
# Кроко пицца и роллы      https://yandex.ru/maps/org/kroko_pitstsa_i_rol...
# Галерея                   https://yandex.ru/maps/org/galereya/149854503334
# Смокерная                https://yandex.ru/maps/org/smokernaya/16733042178
# Сахар                       https://yandex.ru/maps/org/sakhar/220267115404
# Vasilchuki Chaihona № 1  https://yandex.ru/maps/org/vasilchuki_chaihona...
# Бидон                         https://yandex.ru/maps/org/bidon/34459843530
# Башня                        https://yandex.ru/maps/org/bashnya/1365292204
# Белшашлык                https://yandex.ru/maps/org/belshashlyk/4382647...
# Mesto Grill              https://yandex.ru/maps/org/mesto_grill/5869667...
# Восточный Смак           https://yandex.ru/maps/org/vostochny_smak/1752...
# Стэйси пицца             https://yandex.ru/maps/org/steysi_pitstsa/2040...
# Дикая утка               https://yandex.ru/maps/org/dikaya_utka/1337269...
# Ниндзя ФУД               https://yandex.ru/maps/org/nindzya_fud/1868725...
# Азбука Хлеба             https://yandex.ru/maps/org/azbuka_khleba/72072...
# Yellowcafe.ru            https://yandex.ru/maps/org/yellowcafe_ru/23320...
# Мир шашлыка              https://yandex.ru/maps/org/mir_shashlyka/11804...
# Томато                       https://yandex.ru/maps/org/tomato/58409121216
# Ташир Пицца              https://yandex.ru/maps/org/tashir_pitstsa/1017...
# Surf Coffee X Friends    https://yandex.ru/maps/org/surf_coffee_x_frien...
# Ташир Пицца              https://yandex.ru/maps/org/tashir_pitstsa/1204...
# Корчма                       https://yandex.ru/maps/org/korchma/1214186914
# Артель                       https://yandex.ru/maps/org/artel/115849083421
# Корчма                       https://yandex.ru/maps/org/korchma/1190271420
# Вкусно — и точка         https://yandex.ru/maps/org/vkusno_i_tochka/337...
# Между палок              https://yandex.ru/maps/org/mezhdu_palok/178024...
# Суши ням                 https://yandex.ru/maps/org/sushi_nyam/19239820...
# Перчини Grill&Wine       https://yandex.ru/maps/org/perchini_grill_wine...
# Benny Kitchen            https://yandex.ru/maps/org/benny_kitchen/11496...
# Старик Хинкалыч          https://yandex.ru/maps/org/starik_khinkalych/7...
# Восточное бистро         https://yandex.ru/maps/org/vostochnoye_bistro/...
# Пицца 32 СМ              https://yandex.ru/maps/org/pitstsa_32_sm/24458...
# Перчини Grill&Wine       https://yandex.ru/maps/org/perchini_grill_wine...
#
#                         closing_time               category
# name
# Forest grill                   00:00               Ресторан
# Кофе и Баббл Ти                21:00                Кофейня
# Барашек                        00:00               Ресторан
# Мидийное место                 23:00               Ресторан
# Кофе Вино                      23:00                Кофейня
# Ташир Пицца                    22:00               Пиццерия
# Комод                          23:00                Кофейня
# Лес и Лис                      23:00               Ресторан
# ПАРА-пицца                     22:00  Доставка еды и обедов
# Катана                         22:45  Доставка еды и обедов
# Веретено                       00:00               Ресторан
# Виноград                       00:00               Ресторан
# Lazy Food                      22:00  Доставка еды и обедов
# Кроко пицца и роллы            21:30  Доставка еды и обедов
# Галерея                        00:00               Ресторан
# Смокерная                      22:00  Доставка еды и обедов
# Сахар                          23:00                Кофейня
# Vasilchuki Chaihona № 1        01:00               Ресторан
# Бидон                          23:00               Ресторан
# Башня                          00:00               Ресторан
# Белшашлык                      12:12        Быстрое питание
# Mesto Grill                    00:00               Ресторан
# Восточный Смак                 12:12        Быстрое питание
# Стэйси пицца                   21:45               Пиццерия
# Дикая утка                     23:00                   Кафе
# Ниндзя ФУД                     23:00                   Кафе
# Азбука Хлеба                   20:00  Доставка еды и обедов
# Yellowcafe.ru                  21:00  Доставка еды и обедов
# Мир шашлыка                    23:00                   Кафе
# Томато                         22:00               Ресторан
# Ташир Пицца                    21:00               Пиццерия
# Surf Coffee X Friends          23:00                Кофейня
# Ташир Пицца                    22:00               Пиццерия
# Корчма                         00:00               Ресторан
# Артель                         00:02                   Кафе
# Корчма                         00:00               Ресторан
# Вкусно — и точка               22:00        Быстрое питание
# Между палок                    23:00  Доставка еды и обедов
# Суши ням                       23:00  Доставка еды и обедов
# Перчини Grill&Wine             23:00               Ресторан
# Benny Kitchen                  00:00                   Кафе
# Старик Хинкалыч                22:00                   Кафе
# Восточное бистро               02:00        Быстрое питание
# Пицца 32 СМ                    01:45               Пиццерия
# Перчини Grill&Wine             23:00               Ресторан
