# %% [markdown]
# <h1>Basic of matplotlib</h1>
# <a href='https://matplotlib.org/stable/users/explain/quick_start.html'>matplotlib doc</a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()             # Create a figure containing a single Axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data on the Axes.
plt.show()                           # Show the figure.

# %% [markdown]
# <img src='https://matplotlib.org/stable/_images/anatomy.png'> base parts

# %%
fig = plt.figure()             # an empty figure with no Axes
fig, ax = plt.subplots()       # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
# a figure with one Axes on the left, and two on the right:
fig, axs = plt.subplot_mosaic([['left', 'right_top'],
                               ['left', 'right_bottom']])

# %%
ax1 = plt.subplot(1,3,1)
plt.plot(np.random.random(10))
ax2 = plt.subplot(1,3,2)
plt.plot(np.random.random(10))
ax3 = plt.subplot(1,3,3)
plt.plot(np.random.random(10))

ax1.grid()
ax2.grid()
ax3.grid()

# %%
ax1 = plt.subplot(2,3,1)
plt.plot(np.random.random(10))
ax2 = plt.subplot(2,3,2)
plt.plot(np.random.random(10))
ax3 = plt.subplot(2,3,3)
plt.plot(np.random.random(10))
ax4 = plt.subplot(2, 1, 2)
plt.plot(np.random.random(10))

ax1.grid()
ax2.grid()
ax3.grid()

# %%
f, ax = plt.subplots(2, 2)

f.set_size_inches(7 ,4)
f.set_facecolor('#eee')

ax[0, 0].plot(np.arange(0, 8))
ax[0, 0].grid()

ax[0, 1].plot(np.arange(8, 0, -1))
ax[0, 1].grid()

# %%
from ma

fig = plt.figure(figsize=(7,4))
gs = GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = plt.subplot(gs[0,0])
ax1.plot(np.arange(6))
ax2 = fig.add_subplot(gs[1, 0:2])
ax2.plot(np.random.randint(low=0, hight=10, size=(8)))
ax3 = fig.add_subplot(gs[:, 2])
ax3.plot(np.random.randint(low=0, hight=10, size=(8)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 fig = plt.figure(figsize=(7,4))
# ----> 2 gs = GridSpec(ncols=3, nrows=2, figure=fig)
#       4 ax1 = plt.subplot(gs[0,0])
#       5 ax1.plot(np.arange(6))
#
# NameError: name 'GridSpec' is not defined
